# %%
# !pip install Pillow

# %%
import steganography as steg

# %%
i = steg.encode('Charge600.jpg', 'Into the valley of death rode the 600.', 'R1')
steg.write('jojo.png',i)
t = steg.decode('jojo.png','R1')
print(t)
